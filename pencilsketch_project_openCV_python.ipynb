# %%
from google.colab import files
from IPython import display

# %%
image=files.upload()
# Out:
#      <input type="file" id="files-13a7b52b-d353-4473-a1da-06832d8cd561" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-13a7b52b-d353-4473-a1da-06832d8cd561">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving lathaa pic.jpeg to lathaa pic.jpeg

# %%
display.Image("lathaa pic.jpeg",width=500)

# %%
from google.colab.patches import cv2_imshow

# %%
import cv2

# %%
img=cv2.imread("lathaa pic.jpeg")

# %%
cv2_imshow (img)
# Out:
# <PIL.Image.Image image mode=RGB size=959x1280 at 0x7FF2B2CB3630>

# %%
import cv2

img_rgb = cv2.imread("lathaa pic.jpeg")
img_gray = cv2.cvtColor(img_rgb, cv2.COLOR_BGR2GRAY)

# %%
cv2_imshow(img_gray)
# Out:
# <PIL.Image.Image image mode=L size=959x1280 at 0x7FF2B2C71A90>

# %%
img_gray_inv = cv2.bitwise_not(img_gray)

# %%
cv2_imshow (img_gray_inv)
# Out:
# <PIL.Image.Image image mode=L size=959x1280 at 0x7FF2B2C7D978>

# %%
img_blur = cv2.GaussianBlur(img_gray_inv, ksize=(21, 21),
                            sigmaX=0, sigmaY=0)

# %%
cv2_imshow (img_blur)
# Out:
# <PIL.Image.Image image mode=L size=959x1280 at 0x7FF2B2C7DB00>

# %%
def dodgeV2(image, mask):
  return cv2.divide(image, 255-mask, scale=256)

# %%
pencilsketch=dodgeV2(img_gray,img_blur)

# %%
cv2_imshow(pencilsketch)
# Out:
# <PIL.Image.Image image mode=L size=959x1280 at 0x7FF2B2C94390>
